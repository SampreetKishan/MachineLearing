# %% [markdown]
# # E-Commerce website analysis using Linear Regression

# %% [markdown]
# *Youtube link: https://www.youtube.com/watch?v=O2Cw82YR5Bo&t=75s <br>
# Kaggle link: https://www.kaggle.com/datasets/kolawale/focusing-on-mobile-app-or-website/data*

# %% [markdown]
# ### Objective: The company is trying to decide whether to focus their efforts on their mobile app experience or their website

# %%
#Let's import the necessary modueles
import pandas as pd
import os 
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
#Let's read the dataset
raw_dataset = pd.read_csv("ECommerceCustomers.csv")

# %% [markdown]
# ## Exploratory Data Analysis

# %%
print(raw_dataset.head(5))
# Out:
#                            Email  \
# 0      mstephenson@fernandez.com
# 1              hduke@hotmail.com
# 2               pallen@yahoo.com
# 3        riverarebecca@gmail.com
# 4  mstephens@davidson-herman.com
#
#                                              Address            Avatar  \
# 0       835 Frank Tunnel\nWrightmouth, MI 82180-9605            Violet
# 1     4547 Archer Common\nDiazchester, CA 06566-8576         DarkGreen
# 2  24645 Valerie Unions Suite 582\nCobbborough, D...            Bisque
# 3   1414 David Throughway\nPort Jason, OH 22070-1220       SaddleBrown
# 4  14023 Rodriguez Passage\nPort Jacobville, PR 3...  MediumAquaMarine
#
#    Avg. Session Length  Time on App  Time on Website  Length of Membership  \
# 0            34.497268    12.655651        39.577668              4.082621
# 1            31.926272    11.109461        37.268959              2.664034
# 2            33.000915    11.330278        37.110597              4.104543
# 3            34.305557    13.717514        36.721283              3.120179
# 4            33.330673    12.795189        37.536653              4.446308
#
#    Yearly Amount Spent
# 0           587.951054
# 1           392.204933
# 2           487.547505
# 3           581.852344
# 4           599.406092

# %%
#Let's try to clean up the dataset
print("Number of rows in the raw dataset: ", raw_dataset.shape[0])

#let's drop rows with missing values
dataset_cleaned = raw_dataset.dropna(axis='index')

print("\nNumber of rows in the cleaned dataset: ", dataset_cleaned.shape[0])

print("\nHere's some information about the dataset: ") 
dataset_cleaned.info()
# Out:
# Number of rows in the raw dataset:  500
#
# Number of rows in the cleaned dataset:  500
#
# Here's some information about the dataset:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 500 entries, 0 to 499
# Data columns (total 8 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Email                 500 non-null    object
#  1   Address               500 non-null    object
#  2   Avatar                500 non-null    object
#  3   Avg. Session Length   500 non-null    float64
#  4   Time on App           500 non-null    float64
#  5   Time on Website       500 non-null    float64
#  6   Length of Membership  500 non-null    float64
#  7   Yearly Amount Spent   500 non-null    float64
# dtypes: float64(5), object(3)
# memory usage: 31.4+ KB

# %%
dataset_cleaned.describe()
# Out:
#        Avg. Session Length  Time on App  Time on Website  \
# count           500.000000   500.000000       500.000000
# mean             33.053194    12.052488        37.060445
# std               0.992563     0.994216         1.010489
# min              29.532429     8.508152        33.913847
# 25%              32.341822    11.388153        36.349257
# 50%              33.082008    11.983231        37.069367
# 75%              33.711985    12.753850        37.716432
# max              36.139662    15.126994        40.005182
#
#        Length of Membership  Yearly Amount Spent
# count            500.000000           500.000000
# mean               3.533462           499.314038
# std                0.999278            79.314782
# min                0.269901           256.670582
# 25%                2.930450           445.038277
# 50%                3.533975           498.887875
# 75%                4.126502           549.313828
# max                6.922689           765.518462

# %% [markdown]
# ### Correlation between the numerical columns

# %%
#Let's look at the correlation between certain columns 
corr_columns = ['Avg. Session Length', 'Time on App', 'Time on Website', 'Length of Membership', 'Yearly Amount Spent']
dataset_cleaned[corr_columns].corr().style.background_gradient(cmap='YlOrRd')
# Out:
# <style type="text/css">
# #T_cf8be_row0_col0, #T_cf8be_row1_col1, #T_cf8be_row2_col2, #T_cf8be_row3_col3, #T_cf8be_row4_col4 {
#   background-color: #800026;
#   color: #f1f1f1;
# }
# #T_cf8be_row0_col1, #T_cf8be_row2_col0, #T_cf8be_row2_col3, #T_cf8be_row2_col4, #T_cf8be_row3_col2 {
#   background-color: #ffffcc;
#   color: #000000;
# }
# #T_cf8be_row0_col2 {
#   background-color: #fffdc8;
#   color: #000000;
# }
# #T_cf8be_row0_col3 {
#   background-color: #fff0a8;
#   color: #000000;
# }
# #T_cf8be_row0_col4 {
#   background-color: #feb852;
#   color: #000000;
# }
# #T_cf8be_row1_col0 {
#   background-color: #fffecb;
#   color: #000000;
# }
# #T_cf8be_row1_col2 {
#   background-color: #ffeda1;
#   color: #000000;
# }
# #T_cf8be_row1_col3 {
#   background-color: #fff5b3;
#   color: #000000;
# }
# #T_cf8be_row1_col4 {
#   background-color: #fd8c3c;
#   color: #f1f1f1;
# }
# #T_cf8be_row2_col1 {
#   background-color: #fff0a7;
#   color: #000000;
# }
# #T_cf8be_row3_col0 {
#   background-color: #fff2ac;
#   color: #000000;
# }
# #T_cf8be_row3_col1 {
#   background-color: #fff7b9;
#   color: #000000;
# }
# #T_cf8be_row3_col4 {
#   background-color: #d00d21;
#   color: #f1f1f1;
# }
# #T_cf8be_row4_col0 {
#   background-color: #feb24c;
#   color: #000000;
# }
# #T_cf8be_row4_col1 {
#   background-color: #fd863a;
#   color: #f1f1f1;
# }
# #T_cf8be_row4_col2 {
#   background-color: #fff9be;
#   color: #000000;
# }
# #T_cf8be_row4_col3 {
#   background-color: #ce0c22;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_cf8be">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_cf8be_level0_col0" class="col_heading level0 col0" >Avg. Session Length</th>
#       <th id="T_cf8be_level0_col1" class="col_heading level0 col1" >Time on App</th>
#       <th id="T_cf8be_level0_col2" class="col_heading level0 col2" >Time on Website</th>
#       <th id="T_cf8be_level0_col3" class="col_heading level0 col3" >Length of Membership</th>
#       <th id="T_cf8be_level0_col4" class="col_heading level0 col4" >Yearly Amount Spent</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_cf8be_level0_row0" class="row_heading level0 row0" >Avg. Session Length</th>
#       <td id="T_cf8be_row0_col0" class="data row0 col0" >1.000000</td>
#       <td id="T_cf8be_row0_col1" class="data row0 col1" >-0.027826</td>
#       <td id="T_cf8be_row0_col2" class="data row0 col2" >-0.034987</td>
#       <td id="T_cf8be_row0_col3" class="data row0 col3" >0.060247</td>
#       <td id="T_cf8be_row0_col4" class="data row0 col4" >0.355088</td>
#     </tr>
#     <tr>
#       <th id="T_cf8be_level0_row1" class="row_heading level0 row1" >Time on App</th>
#       <td id="T_cf8be_row1_col0" class="data row1 col0" >-0.027826</td>
#       <td id="T_cf8be_row1_col1" class="data row1 col1" >1.000000</td>
#       <td id="T_cf8be_row1_col2" class="data row1 col2" >0.082388</td>
#       <td id="T_cf8be_row1_col3" class="data row1 col3" >0.029143</td>
#       <td id="T_cf8be_row1_col4" class="data row1 col4" >0.499328</td>
#     </tr>
#     <tr>
#       <th id="T_cf8be_level0_row2" class="row_heading level0 row2" >Time on Website</th>
#       <td id="T_cf8be_row2_col0" class="data row2 col0" >-0.034987</td>
#       <td id="T_cf8be_row2_col1" class="data row2 col1" >0.082388</td>
#       <td id="T_cf8be_row2_col2" class="data row2 col2" >1.000000</td>
#       <td id="T_cf8be_row2_col3" class="data row2 col3" >-0.047582</td>
#       <td id="T_cf8be_row2_col4" class="data row2 col4" >-0.002641</td>
#     </tr>
#     <tr>
#       <th id="T_cf8be_level0_row3" class="row_heading level0 row3" >Length of Membership</th>
#       <td id="T_cf8be_row3_col0" class="data row3 col0" >0.060247</td>
#       <td id="T_cf8be_row3_col1" class="data row3 col1" >0.029143</td>
#       <td id="T_cf8be_row3_col2" class="data row3 col2" >-0.047582</td>
#       <td id="T_cf8be_row3_col3" class="data row3 col3" >1.000000</td>
#       <td id="T_cf8be_row3_col4" class="data row3 col4" >0.809084</td>
#     </tr>
#     <tr>
#       <th id="T_cf8be_level0_row4" class="row_heading level0 row4" >Yearly Amount Spent</th>
#       <td id="T_cf8be_row4_col0" class="data row4 col0" >0.355088</td>
#       <td id="T_cf8be_row4_col1" class="data row4 col1" >0.499328</td>
#       <td id="T_cf8be_row4_col2" class="data row4 col2" >-0.002641</td>
#       <td id="T_cf8be_row4_col3" class="data row4 col3" >0.809084</td>
#       <td id="T_cf8be_row4_col4" class="data row4 col4" >1.000000</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ### Scatterplots to visualise correlation between different variables

# %%
#Let's use seaborn to create a scatterplot to show the correlation between the different columns
sns.pairplot(dataset_cleaned[corr_columns],kind='reg', plot_kws={'line_kws':{'color':'red'}, 'scatter_kws': {'alpha': 0.1}})

# %% [markdown]
# _We can see a positive correlation between Yearly amount spent and Time on App. However, there is a negative correlation between Yearly amount spent and Time on Website. However, it seems like Yearly amount spent is more closely correlated to the length of membership than it is to Time on App_

# %% [markdown]
# ## Splitting the dataset into train and test datasets

# %%
#Let's build our linear model.
#But before we do that, let's split the data into training and testing data 
from sklearn.model_selection import train_test_split

print("Let's split the dataset into a dataset that contains features and another dataset for the y/target values..\n") 
x_columns = ['Avg. Session Length', 'Time on App', 'Time on Website', 'Length of Membership']
y_column = ['Yearly Amount Spent']
X_data = dataset_cleaned[x_columns]
y_data = dataset_cleaned[y_column]

#print(X_data.head(5))

#print(y_data.head(5))

print("Let's split the datasets into training and testing datasets..")
X_train, X_test, y_train, y_test = train_test_split(X_data, y_data, test_size=0.33, random_state=42)
# Out:
# Let's split the dataset into a dataset that contains features and another dataset for the y/target values..
#
# Let's split the datasets into training and testing datasets..

# %% [markdown]
# ## Creating the model

# %%
from sklearn.linear_model import LinearRegression
print("Let's fit our X_train and y_train datasets to a Linear Regression model") 
print("\nCreating the model")
model = LinearRegression().fit(X_train, y_train)
print("\nR^2 value:",model.score(X_train, y_train))
print("The coefficients are: ", model.coef_) 
print("The intercept is: ", model.intercept_)
# Out:
# Let's fit our X_train and y_train datasets to a Linear Regression model
#
# Creating the model
#
# R^2 value: 0.9854828344906233
# The coefficients are:  [[25.70676165 38.57260842  0.62520092 61.71767604]]
# The intercept is:  [-1056.07205931]

# %% [markdown]
# ## Testing the model

# %%
from sklearn.metrics import mean_squared_error
from sklearn.metrics import mean_absolute_error

#Let's run the model to get predicted values for y (yearly amount spent) for the testing data 
y_predicted = model.predict(X_test)
#y_predicted 

mse = mean_squared_error(y_test, y_predicted)
mae = mean_absolute_error(y_test, y_predicted)

print("The mean squared error: ", mse)
print("The mean absolute error: ", mae) 

y_test_array = y_test.values 

#Looks like both the y_predicted and y_test_array are arrays each and value is stored as an array 
# array([[404.06761931],
#       [542.58543915],
#       [427.34884845],
#        [502.01838314],.....

#We need to convert them into flat one-dimensional arrays 

y_predicted_flat = [item[0] for item in y_predicted]
y_test_flat = [item[0] for item in y_test_array ]

#Let's draw a scatterplot between y_test and y_predicted values 
sns.scatterplot(x=y_test_flat, y=y_predicted_flat)
plt.xlabel('Yearly spent amount values from TEST dataset')
plt.ylabel('Yearly spent amount PREDICTED values')
plt.title('Predicted vs Test values') 
plt.grid(True)
plt.show()
# Out:
# The mean squared error:  102.4042865993187
# The mean absolute error:  8.35357352501755
